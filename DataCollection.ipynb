# %%
from googleapiclient.discovery import build

import pandas as pd

# %%
api_key = 'AIzaSyCVCizl6-O4_NmW8rO5mL5JwUfkPleKuAw'
yt = build('youtube','v3',developerKey=api_key)
maxResults = 50

# %%
trendingVideos = yt.videos().list(part='snippet,contentDetails,statistics',chart='mostPopular',regionCode='IN',maxResults=maxResults)
respose = trendingVideos.execute()

# %%
import pandas as pd

df = pd.DataFrame(columns=['VideoID','ChannelID','Title','Views','Likes','Comments'])
df
# Out:
# Empty DataFrame
# Columns: [VideoID, ChannelID, Title, Views, Likes, Comments]
# Index: []

# %%
for i in range(maxResults):
    video = dict()
    #'VideoID','ChannelID','Title','Views','Likes','Comments'
    video.setdefault('VideoID',response['items'][i]['id'])
    video.setdefault('ChannelID',response['items'][i]['snippet']['channelId'])
    video.setdefault('Title',response['items'][i]['snippet']['title'])
    video.setdefault('Views',response['items'][i]['statistics']['viewCount'])
    video.setdefault('Likes',response['items'][i]['statistics']['likeCount'])
    video.setdefault('Comments',response['items'][i]['statistics']['commentCount'])
    #print(video['Comments'])
    df = df.append(video,ignore_index=True)

# %%
df
# Out:
#         VideoID                 ChannelID  \
# 0   6GxXehkPyBs  UCbTLwN10NoCU4WDzLf1JMOA
# 1   V47eD4nMP80  UCNc5QKnJ8vyGhed6tC2h1DA
# 2   FpRq9C6C19g  UCHmk8iNJHvf5mGN6_pkPc7g
# 3   d3O2cnQHItg  UC_vcKmg67vjMP7ciLnSxSHQ
# 4   YRD-G_v-xm8  UCCLdGxMC4fwkaQ4AIcL7Z8w
# 5   TkUTJlIZmQs  UCk3JZr7eS3pg5AGEvBdEvFg
# 6   teF5k_Yz9TY  UCueYcgdqos0_PzNOq81zAFg
# 7   GbXtCRCT0Ig  UC_Q-YjEXDN0ufkU4AoWhU1g
# 8   lvR0hmnLJSo  UClfos9f7uDdoun8ZyE9jYFg
# 9   kJv8ifZplmM  UCAji-oxSI2xAS8xN_TuVP4A
# 10  mPilxfwBJ68  UCarJoVXH0T2pdtcHBu9J8Bw
# 11  C9jSvqmUx6E  UCfLuT3JwLx8rvHjHfTymekw
# 12  2u80yFDtszE  UC7b2A4OTNe5es8aJoAVRDfQ
# 13  C_Ff1nGnEqE  UCMBhVE6pOpLuQ-4TxWagBvQ
# 14  8YnkDl05BTw  UCumU_6FNxfHXTmeeFCYz6Yw
# 15  jYb7FMlYdBw  UC7b2A4OTNe5es8aJoAVRDfQ
# 16  foK9yO-wNF8  UCXS0LXj5BO9CS8uVBFPBvrg
# 17  JRU8WHomWWE  UCSM54qcBP60U61HOMm_SUqA
# 18  SRNw-NBE9bQ  UC2txjRLvlsKzDdt-hn3_Gjg
# 19  cWMxCE2HTag  UC3XBkDeCVXCoCofFgfUZXGw
# 20  MMTEgDXHv5Y  UC68nKdrLbLL0Vj7ilVkLmmg
# ...
